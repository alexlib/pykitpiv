# %% [markdown]
# <a id='top-page'></a>
# # `pykitPIV` demo: Learn to locate sources/sinks in a 2D PIV experiment using reinforcement learning
#
# ## Single deep Q-network without memory replay
#
# In this Jupyter notebook, we show how the available functionalities from the machine learning module (`pykitPIV.ml`) can be used to train a reinforcement learning (RL) agent to navigate the virtual PIV camera towards sources/sinks in a radial flow.
#
# We use a **single deep Q-learning** agent without memory replay, as implemented in the class [`pykitPIV.ml.CameraAgentSingleDQN`](https://pykitpiv.readthedocs.io/en/latest/user/ml.html#pykitPIV.ml.CameraAgentSingleDQN).
#
# Note that other RL algorithms are also possible, such as double deep Q-learning with memory replay (see other camera agent classes implemented in the `pykitPIV.ml` module).
#
# The agent can perform one of the five actions:
#
# - Move up
# - Move down
# - Move right
# - Move left
# - Stay
#
# on the virtual camera, thereby with each step it moves the virtual PIV camera in 2D by $N$ pixels.
#
# The illustration below shows the single reinforcement learning loop:
#
# <div style="text-align:center;">
#     <img src="../docs/images/PIVEnv.svg" style="height:500px">
# </div>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <font size="3"><strong>Table of contents:</strong></font>
# <br>
# <ol>
#     <li><a href="#initializations">Initializations</a></li>
#     <ul>
#         <li><a href="#prepare-specs">Prepare specifications for <code>pykitPIV</code> parameters</a></li>
#         <li><a href="#prepare-inference">Prepare the CNN-based inference model for PIV images</a></li>
#     </ul>
#     <li><a href="#create-env">Create the RL environment</a></li>
#     <li><a href="#create-agent">Create and train the RL agent</a></li>
#     <ul>
#         <li><a href="#visualize-training">Visualize the training metrics and the training progress</a></li>
#         <li><a href="#visualize-policy">Visualize the learned policy in the training environment</a></li>
#     </ul>
#     <li><a href="#test-agent">Test the trained agent in a new environment</a></li>
#     <ul>
#         <li><a href="#visualize-test">Visualize the learned policy in the test environment</a></li>
#         <li><a href="#visualize-trajectory">Visualize one sample trajectory in the test environment</a></li>
#     </ul>
# </ol>
# <p></p>
# </div>
# <br>
#
# ***

# %%
from pykitPIV.ml import PIVEnv, CameraAgentSingleDQN, Rewards, Cues, plot_trajectory
from pykitPIV.flowfield import compute_q_criterion, compute_divergence
from pykitPIV import ParticleSpecs, FlowFieldSpecs, MotionSpecs, ImageSpecs
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.colors import ListedColormap
import cmcrameri.cm as cmc
import numpy as np
import onnxruntime
import tensorflow as tf
import pandas as pd
import h5py
import torch
import sys, os
import time
import copy as cp
# Out:
# 2025-08-12 10:43:46.799802: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
save_images = False
filename = None

# %%
action_colors = cmc.batlow(np.linspace(0, 1, 5))
cmap_actions = ListedColormap(action_colors)

# %% [markdown]
# Specify the size of the interrogation window and the buffer size:

# %%
interrogation_window_size = (40,40)
interrogation_window_size_buffer = 3

# %% [markdown]
# Specify the time separation, $\Delta t$, between two PIV image frames:

# %%
time_separation = 2

# %% [markdown]
# <a class="anchor" id='initializations'></a>
# ***
#
# ## Initializations
#
# [Go to the top](#top-page)

# %% [markdown]
# <a id='prepare-specs'></a>
#
# ### Prepare specifications for pykitPIV parameters
#
# [Go to the top](#top-page)

# %%
particle_spec = ParticleSpecs(diameters=(1, 1),
                              distances=(2, 2),
                              densities=(0.4, 0.4),
                              diameter_std=0,
                              seeding_mode='random')

print(particle_spec)
# Out:
# ParticleSpecs(n_images=1,
# size=(512, 512),
# size_buffer=10,
# diameters=(1, 1),
# distances=(2, 2),
# densities=(0.4, 0.4),
# diameter_std=0,
# min_diameter=0.01,
# seeding_mode='random',
# dtype=<class 'numpy.float64'>,
# random_seed=None)

# %%
flowfield_spec = FlowFieldSpecs(size=(200,300),
                                time_separation=time_separation,
                                flowfield_type='radial',
                                radial_epsilon=1e-6,
                                radial_source=True,
                                radial_sigma=20,
                                radial_imposed_source_location=None,
                                displacement=(2, 2))

print(flowfield_spec)
# Out:
# FlowFieldSpecs(n_images=1,
# size=(200, 300),
# size_buffer=10,
# time_separation=2,
# random_seed=None,
# flowfield_type='radial',
# gaussian_filters=(10, 10),
# n_gaussian_filter_iter=10,
# displacement=(2, 2),
# constant_u_magnitude=(1, 4),
# constant_v_magnitude=(1, 4),
# radial_source=True,
# radial_imposed_source_location=None,
# radial_sigma=20,
# radial_epsilon=1e-06,
# directionally_divergent_imposed_origin=(0, 0),
# directionally_divergent_directions=['x', 'y', 'both'],
# directionally_divergent_sources=[True, False],
# taylor_green_k=1,
# imposed_origin=(0, 0),
# apply_SLM=False,
# integral_time_scale=1,
# sigma=1,
# n_stochastic_particles=1000000,
# n_iterations=100,
# dtype=<class 'numpy.float64'>)

# %%
motion_spec = MotionSpecs(n_steps=10,
                          particle_loss=(0, 0),
                          particle_gain=(0, 0))

print(motion_spec)
# Out:
# MotionSpecs(n_images=1,
# size=(512, 512),
# size_buffer=10,
# n_steps=10,
# particle_loss=(0, 0),
# particle_gain=(0, 0),
# dtype=<class 'numpy.float64'>,
# random_seed=None)

# %%
image_spec = ImageSpecs(exposures=(0.98, 0.98),
                        maximum_intensity=2**16-1,
                        laser_beam_thickness=1,
                        laser_over_exposure=1,
                        laser_beam_shape=0.95,
                        alpha=1/8,
                        clip_intensities=True,
                        normalize_intensities=False)

print(image_spec)
# Out:
# ImageSpecs(n_images=1,
# size=(512, 512),
# size_buffer=10,
# random_seed=None,
# exposures=(0.98, 0.98),
# maximum_intensity=65535,
# laser_beam_thickness=1,
# laser_over_exposure=1,
# laser_beam_shape=0.95,
# no_laser_plane=False,
# alpha=0.125,
# extend_gaussian=1,
# covariance_matrix=None,
# clip_intensities=True,
# normalize_intensities=False,
# dtype=<class 'numpy.float64'>)

# %% [markdown]
# <a id='prepare-inference'></a>
#
# ***
#
# ### Prepare the CNN-based inference model for PIV images
#
# [Go to the top](#top-page)

# %% [markdown]
# Below we upload the trained LIMA model as the inference model to predict flow targets from PIV images.
#
# Note that the RL agent can also be trained on ground truth, which is a more reliable and faster option for training off-line. However, when connecting RL with real experimentation, we do not have access to ground truth and only an approximation of the true displacement fields are available.

# %%
class ONNXmodel:
    
    def __init__(self,
                 onnx_file_path):
        
        self.name = "ONNX"
        self.providers = ['CPUExecutionProvider']
        self.session = onnxruntime.InferenceSession(onnx_file_path, 
                                                    None,
                                                    providers=self.providers)

        self.input_name = self.session.get_inputs()[0].name  
        print('Input Name:', self.input_name)   
 
    def inference(self, x):
        
        output = self.session.run([], {self.input_name:x/np.max(x)})[0] 
      
        return output

    def empty(self):
        
         with torch.no_grad():
            torch.cuda.empty_cache()

# %%
model_file = '../docs/data/Lima_L4_PAD_SR2_dyn.onnx'
print("model:", model_file, '  exist:', os.path.exists(model_file))
# Out:
# model: ../docs/data/Lima_L4_PAD_SR2_dyn.onnx   exist: True

# %%
lima_inference_model = ONNXmodel(model_file)
# Out:
# Input Name: Input

# %% [markdown]
# <a id=create-env></a>
#
# ***
#
# ## Create the RL environment
#
# [Go to the top](#top-page)

# %% [markdown]
# Define the sensory cues that the RL agent effectively senses and learns from:

# %%
cues_obj = Cues(sample_every_n=10, 
                normalize_displacement_vectors=False)

cues_function = cues_obj.sampled_vectors

# %% [markdown]
# Initialize the `Gymnasium`-based virtual wind tunnel environment using the `PIVEnv` class:

# %%
env = PIVEnv(interrogation_window_size=interrogation_window_size,
             interrogation_window_size_buffer=interrogation_window_size_buffer,
             cues_function=cues_function,
             particle_spec=particle_spec,
             motion_spec=motion_spec,
             image_spec=image_spec,
             flowfield_spec=flowfield_spec,
             user_flowfield=None,
             inference_model=None,
             random_seed=None)

# %%
camera_position, cues = env.reset(imposed_camera_position=np.array([40, 20]), regenerate_flowfield=True)

# %% [markdown]
# Inspect how many sensory cues this agent will see (these become the inputs to the single deep Q-network):

# %%
cues.shape
# Out:
# (1, 32)

# %%
if save_images: filename = 'ml_PIVEnv_render.png'
plt = env.render(quantity=None,
                 camera_position=camera_position,
                 c='white',
                 s=20,
                 lw=1,
                 normalize_cbars=True,
                 cmap=cmc.roma,
                 add_streamplot=True,
                 streamplot_density=1,
                 streamplot_color='k',
                 streamplot_linewidth=0.5,
                 figsize=(10,5), 
                 filename=filename)

# %% [markdown]
# <a id=create-agent></a>
#
# ***
#
# ## Create and train the RL agent
#
# [Go to the top](#top-page)

# %% [markdown]
# We will train the RL agent on 5000 episodes, where at the beginning of each new episose, a new radial field is generated:

# %%
n_episodes = 5000

# %% [markdown]
# The number of episodes for logging information about training:

# %%
log_every = 50

# %% [markdown]
# We will let the RL agent take 20 steps (camera movements) per episode:

# %%
n_iterations = 20

# %% [markdown]
# Each step will be magnified 10 times, i.e., instead of the step being a movement of camera by 1px, it will be a movement by 10px:

# %%
magnify_step = 10

# %% [markdown]
# Define the discount factor for the future rewards, $\gamma$:

# %%
discount_factor = 0.95

# %% [markdown]
# Specify the parameters for the $\varepsilon$-greedy policy:

# %%
epsilon_start = 0.5
epsilon_end = 0.0
n_episodes_epsilon_decay = int(9/10 * n_episodes)

# %% [markdown]
# Specify the parameters for the learning rate decay:

# %%
initial_learning_rate = 0.001
alpha_lr = 0.01
n_episodes_learning_rate_decay = int(9/10 * n_episodes)

# %% [markdown]
# Specify the kernel initializer for the weights in the Q-network:

# %%
kernel_initializer = tf.keras.initializers.RandomUniform

# %% [markdown]
# Specify the gradient descent optimizer to use, it can be `'RMSprop'` or `'Adam'`:

# %%
optimizer = 'Adam'

# %% [markdown]
# Define the exploration probability decay:

# %%
def epsilon_decay(episode, 
                  epsilon_start,
                  epsilon_end,
                  n_decay_steps):
    
    if episode < n_decay_steps:
        return epsilon_start - (episode / n_decay_steps) * (epsilon_start - epsilon_end)
    else:
        return epsilon_end

# %%
exploration_probabilities = []

for i in range(0,n_episodes):

    exploration_probabilities.append(epsilon_decay(i, epsilon_start, epsilon_end, n_decay_steps=n_episodes_epsilon_decay))

# %% [markdown]
# Inspect how the exploration probability will be decayed over the episodes:

# %%
plt.figure(figsize=(6,3))
plt.plot(exploration_probabilities, c='k', lw=3)
plt.xlabel('Episode')
plt.ylabel(r'Exploration probability, $\varepsilon$');

# %% [markdown]
# Define the cosine learning rate decay:

# %%
def learning_rate_decay(episode, 
                        initial_learning_rate, 
                        alpha_lr, 
                        n_decay_steps):
    
    episode = np.min([episode, n_decay_steps])
    cosine_decay = 0.5 * (1 + np.cos(np.pi * episode / n_decay_steps))
    decayed = (1 - alpha_lr) * cosine_decay + alpha_lr
    
    return initial_learning_rate * decayed

# %%
decayed_learning_rates = []

for i in range(0,n_episodes):

    decayed_learning_rates.append(learning_rate_decay(i,
                                                      initial_learning_rate=initial_learning_rate, 
                                                      alpha_lr=alpha_lr, 
                                                      n_decay_steps=n_episodes_learning_rate_decay))

# %% [markdown]
# Inspect how the learning rate will be decayed over the episodes:

# %%
plt.figure(figsize=(6,3))
plt.semilogy(decayed_learning_rates, c='k', lw=3)
plt.xlabel('Episode')
plt.ylabel(r'Learning rate, $\alpha$');

# %% [markdown]
# We define the architecture for the deep Q-network:

# %%
# size_of_hidden_unit = int(env.n_cues/2)
size_of_hidden_unit = 64
size_of_hidden_unit
# Out:
# 64

# %%
class QNetwork(tf.keras.Model):

    def __init__(self, n_actions, kernel_initializer):

        super(QNetwork, self).__init__()

        self.dense1 = tf.keras.layers.Dense(env.n_cues, activation='relu', kernel_initializer=kernel_initializer)
        self.dense2 = tf.keras.layers.Dense(size_of_hidden_unit, activation='relu', kernel_initializer=kernel_initializer)
        self.dense3 = tf.keras.layers.Dense(size_of_hidden_unit, activation='relu', kernel_initializer=kernel_initializer)
        self.output_layer = tf.keras.layers.Dense(n_actions, activation='relu', kernel_initializer=kernel_initializer)

    def call(self, state):

        x = self.dense1(state)
        x = self.dense2(x)
        x = self.dense3(x)

        return self.output_layer(x)

# %% [markdown]
# Initialize the camera agent using the `CameraAgentSingleDQN` class:

# %%
ca = CameraAgentSingleDQN(env=env,
                          q_network=QNetwork(env.n_actions, kernel_initializer),
                          learning_rate=initial_learning_rate,
                          optimizer=optimizer,
                          discount_factor=discount_factor)
# Out:
# The uploaded environment has 5 actions.

# %% [markdown]
# We are going to use the reward based on divergence:

# %%
rewards = Rewards(verbose=False)
reward_function = rewards.divergence

# %% [markdown]
# Define a transformation function for the reward which is appropriate to detecting regions of high divergence:

# %%
def reward_transformation(div): 
    return float(np.mean(np.abs(div)))

# %% [markdown]
# Run training of the RL agent. Note that we are regenerating the radial flowfield at the beginning of each episode to present as many unseen scenarios during training as possible. This should help in training and generalization.

# %%
total_tic = time.perf_counter()

print()
print('- '*20)
print('Starting training the RL agent...\n')

tic = time.perf_counter()

iter_count = 0

collected_rewards = []
collected_average_rewards = []
collected_logged_episodes = []

current_lr = cp.deepcopy(initial_learning_rate)

batch_q_values_collected = np.zeros((1, env.n_actions))

average_reward = 0.0

for episode in range(0, n_episodes):

    camera_position, cues = ca.env.reset(regenerate_flowfield=True)
    
    total_reward = 0.0

    # Exploration probability decreases with training time:
    epsilon = epsilon_decay(episode=iter_count, 
                            epsilon_start=epsilon_start,
                            epsilon_end=epsilon_end,
                            n_decay_steps=n_episodes_epsilon_decay)

    # Decay the learning rate:
    current_lr = learning_rate_decay(episode=iter_count, 
                                     initial_learning_rate=initial_learning_rate, 
                                     alpha_lr=alpha_lr, 
                                     n_decay_steps=n_episodes_learning_rate_decay)
    
    iter_count += 1

    if (episode) % log_every == 0:

        print(f'Episode: {episode + 1}')
        print(f'Epsilon: {epsilon:0.3f}')
        print('Learning rate: ' + str(current_lr))

    # In each episode, take a number of iterations in the environment:
    for i in range(0,n_iterations):

        # Select an action:
        action = ca.choose_action(cues,
                                  epsilon=epsilon)

        next_camera_position, next_cues, reward = ca.env.step(action,
                                                              reward_function=reward_function,
                                                              reward_transformation=reward_transformation,
                                                              magnify_step=magnify_step,
                                                              verbose=False)


        total_reward += reward
        average_reward += reward

        # Train the RL agent with the current step:
        ca.train(cues=cues,
                 action=action,
                 reward=reward,
                 next_cues=next_cues,
                 new_learning_rate=current_lr)

        cues = next_cues
    
    batch_q_values = ca.q_network(cues, training=False).numpy()
    batch_q_values_collected = np.vstack((batch_q_values_collected, batch_q_values))

    if (episode) % log_every == 0:

        toc = time.perf_counter()

        collected_average_rewards.append(average_reward/log_every)
        collected_logged_episodes.append(episode)

        print(f"Average reward: {(average_reward/log_every):0.1f}")
        print(f'These episodes took: {(toc - tic):0.1f} sec.')
        print('- '*15)
        print()

        average_reward = 0.0

        tic = time.perf_counter()

    collected_rewards.append(total_reward)

batch_q_values_collected = batch_q_values_collected[1::,:]

total_toc = time.perf_counter()
print()
print('- '*20)
print(f'Total training time: {(total_toc - total_tic)/60:0.1f} minutes.')
# Out:
# - - - - - - - - - - - - - - - - - - - -
# Starting training the RL agent...
#
# Episode: 1
# Epsilon: 0.500
# Learning rate: 0.001
# Average reward: 0.0
# These episodes took: 1.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 51
# Epsilon: 0.494
# Learning rate: 0.0009996984593744526
# Average reward: 1.2
# These episodes took: 44.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 101
# Epsilon: 0.489
# Learning rate: 0.0009987942048786129
# Average reward: 1.0
# These episodes took: 44.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 151
# Epsilon: 0.483
# Learning rate: 0.0009972883382072953
# Average reward: 1.2
# These episodes took: 46.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 201
# Epsilon: 0.478
# Learning rate: 0.0009951826940270774
# Average reward: 1.0
# These episodes took: 47.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 251
# Epsilon: 0.472
# Learning rate: 0.000992479837741043
# Average reward: 1.0
# These episodes took: 47.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 301
# Epsilon: 0.467
# Learning rate: 0.0009891830623632338
# Average reward: 1.5
# These episodes took: 42.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 351
# Epsilon: 0.461
# Learning rate: 0.0009852963845066183
# Average reward: 1.4
# These episodes took: 42.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 401
# Epsilon: 0.456
# Learning rate: 0.000980824539489468
# Average reward: 1.5
# These episodes took: 44.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 451
# Epsilon: 0.450
# Learning rate: 0.0009757729755661011
# Average reward: 1.4
# These episodes took: 45.8 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 501
# Epsilon: 0.444
# Learning rate: 0.0009701478472890247
# Average reward: 1.6
# These episodes took: 45.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 551
# Epsilon: 0.439
# Learning rate: 0.0009639560080105599
# Average reward: 1.2
# These episodes took: 45.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 601
# Epsilon: 0.433
# Learning rate: 0.0009572050015330874
# Average reward: 1.6
# These episodes took: 47.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 651
# Epsilon: 0.428
# Learning rate: 0.0009499030529180877
# Average reward: 1.3
# These episodes took: 45.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 701
# Epsilon: 0.422
# Learning rate: 0.0009420590584651689
# Average reward: 1.3
# These episodes took: 41.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 751
# Epsilon: 0.417
# Learning rate: 0.0009336825748732972
# Average reward: 1.4
# These episodes took: 40.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 801
# Epsilon: 0.411
# Learning rate: 0.0009247838075974309
# Average reward: 1.2
# These episodes took: 36.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 851
# Epsilon: 0.406
# Learning rate: 0.0009153735984147456
# Average reward: 1.7
# These episodes took: 36.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 901
# Epsilon: 0.400
# Learning rate: 0.000905463412215599
# Average reward: 1.5
# These episodes took: 36.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 951
# Epsilon: 0.394
# Learning rate: 0.0008950653230353272
# Average reward: 1.5
# These episodes took: 36.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1001
# Epsilon: 0.389
# Learning rate: 0.0008841919993438941
# Average reward: 1.4
# These episodes took: 37.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1051
# Epsilon: 0.383
# Learning rate: 0.0008728566886113102
# Average reward: 1.5
# These episodes took: 40.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1101
# Epsilon: 0.378
# Learning rate: 0.0008610732011676323
# Average reward: 1.5
# These episodes took: 38.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1151
# Epsilon: 0.372
# Learning rate: 0.0008488558933772037
# Average reward: 1.6
# These episodes took: 36.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1201
# Epsilon: 0.367
# Learning rate: 0.0008362196501476348
# Average reward: 1.4
# These episodes took: 36.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1251
# Epsilon: 0.361
# Learning rate: 0.0008231798667948369
# Average reward: 1.6
# These episodes took: 37.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1301
# Epsilon: 0.356
# Learning rate: 0.0008097524302862009
# Average reward: 1.8
# These episodes took: 37.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1351
# Epsilon: 0.350
# Learning rate: 0.0007959536998847742
# Average reward: 1.7
# These episodes took: 37.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1401
# Epsilon: 0.344
# Learning rate: 0.0007818004872180198
# Average reward: 1.5
# These episodes took: 36.8 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1451
# Epsilon: 0.339
# Learning rate: 0.0007673100357954366
# Average reward: 1.9
# These episodes took: 41.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1501
# Epsilon: 0.333
# Learning rate: 0.0007524999999999999
# Average reward: 1.8
# These episodes took: 40.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1551
# Epsilon: 0.328
# Learning rate: 0.0007373884235790159
# Average reward: 1.4
# These episodes took: 43.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1601
# Epsilon: 0.322
# Learning rate: 0.0007219937176605933
# Average reward: 1.5
# These episodes took: 42.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1651
# Epsilon: 0.317
# Learning rate: 0.0007063346383225211
# Average reward: 1.8
# These episodes took: 42.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1701
# Epsilon: 0.311
# Learning rate: 0.0006904302637408766
# Average reward: 1.8
# These episodes took: 42.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1751
# Epsilon: 0.306
# Learning rate: 0.0006742999709462061
# Average reward: 1.8
# These episodes took: 39.4 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1801
# Epsilon: 0.300
# Learning rate: 0.000657963412215599
# Average reward: 1.6
# These episodes took: 45.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1851
# Epsilon: 0.294
# Learning rate: 0.0006414404911294147
# Average reward: 1.9
# These episodes took: 41.3 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1901
# Epsilon: 0.289
# Learning rate: 0.0006247513383218355
# Average reward: 2.1
# These episodes took: 44.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 1951
# Epsilon: 0.283
# Learning rate: 0.0006079162869547909
# Average reward: 1.7
# These episodes took: 43.4 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2001
# Epsilon: 0.278
# Learning rate: 0.0005909558479451306
# Average reward: 1.8
# These episodes took: 52.3 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2051
# Epsilon: 0.272
# Learning rate: 0.0005738906849752324
# Average reward: 1.8
# These episodes took: 49.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2101
# Epsilon: 0.267
# Learning rate: 0.0005567415893174885
# Average reward: 1.8
# These episodes took: 44.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2151
# Epsilon: 0.261
# Learning rate: 0.0005395294545033422
# Average reward: 1.8
# These episodes took: 44.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2201
# Epsilon: 0.256
# Learning rate: 0.000522275250867738
# Average reward: 1.4
# These episodes took: 44.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2251
# Epsilon: 0.250
# Learning rate: 0.000505
# Average reward: 1.9
# These episodes took: 47.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2301
# Epsilon: 0.244
# Learning rate: 0.00048772474913226217
# Average reward: 1.9
# These episodes took: 39.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2351
# Epsilon: 0.239
# Learning rate: 0.00047047054549665806
# Average reward: 1.9
# These episodes took: 40.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2401
# Epsilon: 0.233
# Learning rate: 0.0004532584106825116
# Average reward: 2.0
# These episodes took: 38.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2451
# Epsilon: 0.228
# Learning rate: 0.0004361093150247676
# Average reward: 2.0
# These episodes took: 39.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2501
# Epsilon: 0.222
# Learning rate: 0.0004190441520548695
# Average reward: 2.0
# These episodes took: 46.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2551
# Epsilon: 0.217
# Learning rate: 0.0004020837130452091
# Average reward: 2.1
# These episodes took: 43.3 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2601
# Epsilon: 0.211
# Learning rate: 0.0003852486616781646
# Average reward: 1.8
# These episodes took: 38.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2651
# Epsilon: 0.206
# Learning rate: 0.0003685595088705854
# Average reward: 2.0
# These episodes took: 38.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2701
# Epsilon: 0.200
# Learning rate: 0.000352036587784401
# Average reward: 1.9
# These episodes took: 38.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2751
# Epsilon: 0.194
# Learning rate: 0.0003357000290537942
# Average reward: 1.8
# These episodes took: 38.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2801
# Epsilon: 0.189
# Learning rate: 0.00031956973625912367
# Average reward: 1.8
# These episodes took: 40.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2851
# Epsilon: 0.183
# Learning rate: 0.00030366536167747893
# Average reward: 2.0
# These episodes took: 43.8 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2901
# Epsilon: 0.178
# Learning rate: 0.0002880062823394068
# Average reward: 2.1
# These episodes took: 40.8 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 2951
# Epsilon: 0.172
# Learning rate: 0.0002726115764209842
# Average reward: 1.8
# These episodes took: 42.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3001
# Epsilon: 0.167
# Learning rate: 0.00025750000000000013
# Average reward: 2.2
# These episodes took: 39.8 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3051
# Epsilon: 0.161
# Learning rate: 0.00024268996420456364
# Average reward: 2.1
# These episodes took: 44.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3101
# Epsilon: 0.156
# Learning rate: 0.0002281995127819804
# Average reward: 1.9
# These episodes took: 43.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3151
# Epsilon: 0.150
# Learning rate: 0.00021404630011522585
# Average reward: 1.8
# These episodes took: 44.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3201
# Epsilon: 0.144
# Learning rate: 0.00020024756971379922
# Average reward: 2.2
# These episodes took: 44.8 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3251
# Epsilon: 0.139
# Learning rate: 0.00018682013320516308
# Average reward: 1.9
# These episodes took: 41.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3301
# Epsilon: 0.133
# Learning rate: 0.00017378034985236518
# Average reward: 2.0
# These episodes took: 45.4 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3351
# Epsilon: 0.128
# Learning rate: 0.00016114410662279634
# Average reward: 2.0
# These episodes took: 54.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3401
# Epsilon: 0.122
# Learning rate: 0.00014892679883236778
# Average reward: 2.0
# These episodes took: 48.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3451
# Epsilon: 0.117
# Learning rate: 0.0001371433113886899
# Average reward: 2.2
# These episodes took: 51.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3501
# Epsilon: 0.111
# Learning rate: 0.00012580800065610596
# Average reward: 2.2
# These episodes took: 44.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3551
# Epsilon: 0.106
# Learning rate: 0.00011493467696467265
# Average reward: 2.2
# These episodes took: 48.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3601
# Epsilon: 0.100
# Learning rate: 0.00010453658778440106
# Average reward: 2.0
# These episodes took: 46.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3651
# Epsilon: 0.094
# Learning rate: 9.462640158525433e-05
# Average reward: 2.2
# These episodes took: 53.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3701
# Epsilon: 0.089
# Learning rate: 8.521619240256914e-05
# Average reward: 2.1
# These episodes took: 52.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3751
# Epsilon: 0.083
# Learning rate: 7.631742512670284e-05
# Average reward: 2.3
# These episodes took: 44.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3801
# Epsilon: 0.078
# Learning rate: 6.794094153483114e-05
# Average reward: 2.4
# These episodes took: 40.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3851
# Epsilon: 0.072
# Learning rate: 6.0096947081912313e-05
# Average reward: 2.5
# These episodes took: 40.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3901
# Epsilon: 0.067
# Learning rate: 5.279499846691252e-05
# Average reward: 2.3
# These episodes took: 37.0 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 3951
# Epsilon: 0.061
# Learning rate: 4.6043991989440176e-05
# Average reward: 2.3
# These episodes took: 36.7 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4001
# Epsilon: 0.056
# Learning rate: 3.9852152710975386e-05
# Average reward: 2.1
# These episodes took: 36.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4051
# Epsilon: 0.050
# Learning rate: 3.4227024433899005e-05
# Average reward: 2.2
# These episodes took: 36.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4101
# Epsilon: 0.044
# Learning rate: 2.9175460510532144e-05
# Average reward: 2.3
# These episodes took: 36.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4151
# Epsilon: 0.039
# Learning rate: 2.4703615493381743e-05
# Average reward: 2.2
# These episodes took: 36.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4201
# Epsilon: 0.033
# Learning rate: 2.081693763676618e-05
# Average reward: 2.2
# These episodes took: 36.8 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4251
# Epsilon: 0.028
# Learning rate: 1.7520162258957028e-05
# Average reward: 2.2
# These episodes took: 37.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4301
# Epsilon: 0.022
# Learning rate: 1.4817305972922726e-05
# Average reward: 2.2
# These episodes took: 36.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4351
# Epsilon: 0.017
# Learning rate: 1.2711661792704722e-05
# Average reward: 2.3
# These episodes took: 37.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4401
# Epsilon: 0.011
# Learning rate: 1.1205795121387023e-05
# Average reward: 2.2
# These episodes took: 37.4 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4451
# Epsilon: 0.006
# Learning rate: 1.0301540625547598e-05
# Average reward: 2.3
# These episodes took: 37.6 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4501
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.1
# These episodes took: 36.9 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4551
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.3
# These episodes took: 37.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4601
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.1
# These episodes took: 37.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4651
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.2
# These episodes took: 37.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4701
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.2
# These episodes took: 38.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4751
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.1
# These episodes took: 39.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4801
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.2
# These episodes took: 39.1 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4851
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.4
# These episodes took: 39.5 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4901
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.5
# These episodes took: 39.2 sec.
# - - - - - - - - - - - - - - -
#
# Episode: 4951
# Epsilon: 0.000
# Learning rate: 1e-05
# Average reward: 2.1
# These episodes took: 40.1 sec.
# - - - - - - - - - - - - - - -
#
#
# - - - - - - - - - - - - - - - - - - - -
# Total training time: 69.5 minutes.

# %% [markdown]
# You can view the current weights and biases:

# %%
WB = ca.view_weights()

# %% [markdown]
# You can also save the current trained deep Q-network. Go to the end of this Jupyter notebook to learn how to upload the trained deep Q-network in the future.

# %%
ca.q_network.save('../docs/data/SingleDQN.keras')

# %% [markdown]
# #### <a id='visualize-training'></a>
#
# ### Visualize the training metrics and the training progress
#
# [Go to the top](#top-page)

# %% [markdown]
# Below, we visualize the rewards received across the training episodes. Notice how at the beginning of training low rewards are obtained by the agent most of the time, but the distribution in rewards shifts as the training progresses. Close to the end of training, the agent is able to get the highest rewards most of the time.

# %%
plt.figure(figsize=(10,3))
plt.scatter([i for i in range(0, len(collected_rewards))], collected_rewards, s=6, c='k')
plt.plot(collected_logged_episodes, collected_average_rewards, '--', c='b', lw=2)
plt.ylabel('Reward [$-$]', fontsize=12)
plt.xlabel('Episode # [$-$]', fontsize=12)
plt.xlim([0, n_episodes])
# Out:
# (0.0, 5000.0)

# %%
MSE_losses_collected = np.array(ca.MSE_losses).ravel()
plt.figure(figsize=(10,3))
plt.semilogy(MSE_losses_collected, color='k', lw=0.2)
plt.ylabel('MSE loss in Q-values [$-$]', fontsize=12)
plt.xlabel('Episode # [$-$]', fontsize=12)
# Out:
# Text(0.5, 0, 'Episode # [$-$]')

# %%
plt.figure(figsize=(10,3))
for i in range(0,env.n_actions):
    plt.semilogy(batch_q_values_collected[:,i], '--', label='$Q_' + str(i+1) + '$: ' + env.action_to_verbose_direction[i], color=action_colors[i], lw=1)
plt.legend(frameon=False)
plt.xlabel('Episode # [$-$]', fontsize=12)
plt.ylabel('Q-value', fontsize=12)
# Out:
# Text(0, 0.5, 'Q-value')

# %% [markdown]
# #### <a id='visualize-policy'></a>
#
# ### Visualize the learned policy in the training environment
#
# [Go to the top](#top-page)

# %% [markdown]
# Create sparse samples of camera position on a uniform grid:

# %%
(_, _, H, W) = ca.env.flowfield.velocity_field_magnitude.shape
(H_adm, W_adm) = ca.env.admissible_observation_space
idx_H = [i for i in range(0, H_adm) if i % 1 == 0]
idx_W = [i for i in range(0, W_adm) if i % 1 == 0]
print(len(idx_H) * len(idx_W))
# Out:
# 39116

# %% [markdown]
# Populate the policy matrix:

# %%
tic = time.perf_counter()

learned_policy = np.ones((H,W)) * np.nan

for h in idx_H:
    for w in idx_W:

        camera_position = np.array([h, w])
        _, cues = ca.env.reset(imposed_camera_position=camera_position)
        q_values = ca.q_network(cues, training=False)
        action = np.argmax(q_values)
        learned_policy[h, w] = action

toc = time.perf_counter()
print(f'\tTime it took: {(toc - tic):0.1f} sec.')
# Out:
# 	Time it took: 220.7 sec.

# %% [markdown]
# Below, we visualize the learned policy that is specific to the environment plotted below. The agent has correctly learned the strategy to navigate the virtual camera to center on the source.

# %%
plt.figure(figsize=(20,5))
plt.imshow(learned_policy, origin='lower', cmap=cmap_actions, vmin=0, vmax=4)
cbar = plt.colorbar()
cbar.set_ticks([4/5*(i+0.5) for i in range(0,5)])
cbar.set_ticklabels(list(env.action_to_verbose_direction.values()))

# %%
if save_images: filename = 'final-environment.png'
plt = ca.env.render(quantity=None,
                    camera_position=None,
                    c='white',
                    s=20,
                    lw=1,
                    normalize_cbars=True,
                    cmap=cmc.roma,
                    add_streamplot=True,
                    streamplot_density=3,
                    streamplot_color='k',
                    streamplot_linewidth=0.3,
                    figsize=(10,6), 
                    filename=filename);

# %% [markdown]
# #### <a id='test-agent'></a>
#
# ***
#
# ## Test the trained agent in a new environment
#
# [Go to the top](#top-page)

# %% [markdown]
# Here, we create a new virtual wind tunnel environment that will allow us to test the learned policy in scenarios where the source can be placed in an arbitrary location.

# %%
particle_spec = ParticleSpecs(diameters=1,
                              distances=2,
                              densities=0.4,
                              diameter_std=0,
                              seeding_mode='random')

print(particle_spec)
# Out:
# ParticleSpecs(n_images=1,
# size=(512, 512),
# size_buffer=10,
# diameters=1,
# distances=2,
# densities=0.4,
# diameter_std=0,
# min_diameter=0.01,
# seeding_mode='random',
# dtype=<class 'numpy.float64'>,
# random_seed=None)

# %%
flowfield_spec = FlowFieldSpecs(size=(200,300),
                                time_separation=1,
                                flowfield_type='radial',
                                radial_epsilon=1e-6,
                                radial_source=True,
                                radial_sigma=20,
                                radial_imposed_source_location=None,
                                displacement=(2, 2))

print(flowfield_spec)
# Out:
# FlowFieldSpecs(n_images=1,
# size=(200, 300),
# size_buffer=10,
# time_separation=1,
# random_seed=None,
# flowfield_type='radial',
# gaussian_filters=(10, 10),
# n_gaussian_filter_iter=10,
# displacement=(2, 2),
# constant_u_magnitude=(1, 4),
# constant_v_magnitude=(1, 4),
# radial_source=True,
# radial_imposed_source_location=None,
# radial_sigma=20,
# radial_epsilon=1e-06,
# directionally_divergent_imposed_origin=(0, 0),
# directionally_divergent_directions=['x', 'y', 'both'],
# directionally_divergent_sources=[True, False],
# taylor_green_k=1,
# imposed_origin=(0, 0),
# apply_SLM=False,
# integral_time_scale=1,
# sigma=1,
# n_stochastic_particles=1000000,
# n_iterations=100,
# dtype=<class 'numpy.float64'>)

# %%
motion_spec = MotionSpecs(n_steps=10,
                          particle_loss=(0, 0),
                          particle_gain=(0, 0))

print(motion_spec)
# Out:
# MotionSpecs(n_images=1,
# size=(512, 512),
# size_buffer=10,
# n_steps=10,
# particle_loss=(0, 0),
# particle_gain=(0, 0),
# dtype=<class 'numpy.float64'>,
# random_seed=None)

# %%
image_spec = ImageSpecs(exposures=0.98,
                        maximum_intensity=2**16-1,
                        laser_beam_thickness=1,
                        laser_over_exposure=1,
                        laser_beam_shape=0.95,
                        alpha=1/8,
                        clip_intensities=True,
                        normalize_intensities=False)

print(image_spec)
# Out:
# ImageSpecs(n_images=1,
# size=(512, 512),
# size_buffer=10,
# random_seed=None,
# exposures=0.98,
# maximum_intensity=65535,
# laser_beam_thickness=1,
# laser_over_exposure=1,
# laser_beam_shape=0.95,
# no_laser_plane=False,
# alpha=0.125,
# extend_gaussian=1,
# covariance_matrix=None,
# clip_intensities=True,
# normalize_intensities=False,
# dtype=<class 'numpy.float64'>)

# %%
test_env = PIVEnv(interrogation_window_size=interrogation_window_size,
                  interrogation_window_size_buffer=interrogation_window_size_buffer,
                  cues_function=cues_function,
                  particle_spec=particle_spec,
                  motion_spec=motion_spec,
                  image_spec=image_spec,
                  flowfield_spec=flowfield_spec,
                  user_flowfield=None,
                  inference_model=None,
                  random_seed=None)

# %%
camera_position, cues = test_env.reset()

# %%
camera_position
# Out:
# array([ 65, 164])

# %%
plt = test_env.render(quantity=None,
                      camera_position=camera_position,
                      c='white',
                      s=20,
                      lw=1,
                      normalize_cbars=True,
                      cmap=cmc.roma,
                      add_streamplot=True,
                      streamplot_density=3,
                      streamplot_color='k',
                      streamplot_linewidth=0.3,
                      figsize=(10,6), 
                      filename=None);

# %%
divergence = compute_divergence(test_env.flowfield.velocity_field)

# %%
plt = test_env.render(quantity=divergence[0,:,:],
                      camera_position=camera_position,
                      c='white',
                      s=20,
                      lw=1,
                      normalize_cbars=True,
                      cmap='coolwarm',
                      add_streamplot=True,
                      streamplot_density=3,
                      streamplot_color='k',
                      streamplot_linewidth=0.3,
                      figsize=(10,6), 
                      filename=None);

# %% [markdown]
# #### <a id='visualize-test'></a>
#
# ### Visualize the learned policy in the test environment
#
# [Go to the top](#top-page)

# %% [markdown]
# Create sparse samples of camera position on a uniform grid:

# %%
(_, _, H, W) = test_env.flowfield.velocity_field_magnitude.shape
(H_adm, W_adm) = test_env.admissible_observation_space
idx_H = [i for i in range(0, H_adm) if i % 1 == 0]
idx_W = [i for i in range(0, W_adm) if i % 1 == 0]
print(len(idx_H) * len(idx_W))
# Out:
# 39116

# %% [markdown]
# Populate the policy matrix:

# %%
tic = time.perf_counter()

learned_policy = np.ones((H,W)) * np.nan

for h in idx_H:
    for w in idx_W:

        camera_position = np.array([h, w])
        _, cues = test_env.reset(imposed_camera_position=camera_position)
        q_values = ca.q_network(cues, training=False)
        action = np.argmax(q_values)
        learned_policy[h, w] = action

toc = time.perf_counter()
print(f'\tTime it took: {(toc - tic):0.1f} sec.')
# Out:
# 	Time it took: 219.8 sec.

# %% [markdown]
# Below, we visualize the learned policy that is specific to the new test environment plotted above.
# The agent has correctly learned the strategy to navigate the virtual camera to center on the source.

# %%
plt.figure(figsize=(20,5))
plt.imshow(learned_policy, origin='lower', cmap=cmap_actions, vmin=0, vmax=4)
cbar = plt.colorbar()
cbar.set_ticks([4/5*(i+0.5) for i in range(0,5)])
cbar.set_ticklabels(list(test_env.action_to_verbose_direction.values()))

# %% [markdown]
# #### <a id='visualize-trajectory'></a>
#
# ### Visualize one sample trajectory in the test environment
#
# [Go to the top](#top-page)

# %% [markdown]
# We are going to take a number of steps in the test environment:

# %%
n_steps = 100

# %%
saved_camera_trajectories = np.zeros((n_steps,2))

# %%
camera_position, cues = test_env.reset(imposed_camera_position=(20,50))

# %%
for i in range(0,n_steps):

    saved_camera_trajectories[i, 0] = camera_position[0]
    saved_camera_trajectories[i, 1] = camera_position[1]

    q_values = ca.q_network(cues, training=False)

    action = np.argmax(q_values)

    print(test_env.action_to_verbose_direction[action])

    camera_position, cues, reward = test_env.step(action=action,
                                                  reward_function=reward_function,
                                                  reward_transformation=reward_transformation,
                                                  magnify_step=10,
                                                  verbose=False)
# Out:
# Right
# Right
# Right
# Right
# Right
# Right
# Right
# Right
# Up
# Right
# Up
# Up
# Right
# Up
# Right
# Right
# Up
# Right
# Right
# Up
# Right
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right
# Left
# Right

# %% [markdown]
# The figure below visualizes the camera trajectory that results from the learned policy.
# Note that the agent correctly moves the camera towards the region of highest divergence.

# %%
if save_images: filename='test-trajectory.png'
plot_trajectory(saved_camera_trajectories,
                quantity=test_env.flowfield.velocity_field_magnitude[0,0,:,:],
                vector_field=test_env.flowfield.velocity_field,
                interrogation_window_size=interrogation_window_size,
                interrogation_window_size_buffer=interrogation_window_size_buffer,
                c_path='white',
                c_init='white',
                c_final='black',
                s=20,
                lw=2,
                xlabel=None,
                ylabel=None,
                xticks=True,
                yticks=True,
                cmap=cmc.roma,
                add_streamplot=True,
                streamplot_density=4,
                streamplot_color='k',
                streamplot_linewidth=0.4,
                figsize=(15,5),
                dpi=300,
                filename=filename);

# %% [markdown]
# We save this final velocity field in the test environment in order to upload it in the next Jupyter notebook.

# %%
u = test_env.flowfield.velocity_field[0,0,:,:]
v = test_env.flowfield.velocity_field[0,1,:,:]

np.savetxt('../docs/data/final-u.csv', (u), delimiter=',', fmt='%.16e')
np.savetxt('../docs/data/final-v.csv', (v), delimiter=',', fmt='%.16e')

# %% [markdown]
# In the next Jupyter notebook, we show how this trained and saved RL model can be uploaded.

# %% [markdown]
# ***
#
# © K. Zdybał, C. Mucignat, S. Kunz, I. Lunati (2025)
